# %% [markdown]
# ## Investigate numpy
#
# import numpy as np
# np.linspace(-5, 5, 100)[0].__class__

# %% [markdown]
# ## Interesting Python libraries
#
# 1. Visualization
#     1. https://plotly.com/examples/
#     1. matplotlib
# 1. Computation, math
#     1. numpy
#     1. scipy
